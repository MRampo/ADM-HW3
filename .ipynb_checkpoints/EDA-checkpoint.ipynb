# %%
from bs4 import BeautifulSoup as bs
import requests
from tqdm import tqdm 
import json
import os
import datetime
import re
import csv
import time
import pandas as pd
from nltk.stem import *
from collections import Counter
from functools import reduce
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import RegexpTokenizer
from nltk.stem import PorterStemmer
from nltk import tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Marco\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# data = load_tsv()
data = pd.read_csv("tsv_dataframe.csv",index_col=0)

#Reset Index
data.reset_index(inplace = True, drop=True)

# %%
data.head()
# Out:
#                       placeName  \
# 0             City Hall Station
# 1  The Winchester Mystery House
# 2      Center for Puppetry Arts
# 3       Amityville Horror House
# 4       Yuma Territorial Prison
#
#                                            placeTags  numPeopleVisited  \
# 0  subways,subterranean,infrastructure,subterrane...              1834
# 1  follies and grottoes,outsider architecture,ecc...              3723
# 2                      sesame street,puppets,museums               705
# 3  hoaxes and pseudoscience,haunted,film location...               367
# 4                       prisons,crime and punishment               422
#
#    numPeopleWant                                          placeDesc  \
# 0           8603  The first New York City subway was built and o...
# 1           5209  In 1886 an eccentric woman named Sarah Winches...
# 2           1027  If you know your Gonzo from your Gelflings, yo...
# 3            831  On a cold November night in 1974, Amityville, ...
# 4            833  On July 1, 1876, the first seven inmates enter...
#
#                                       placeShortDesc  \
# 0  A beautiful and abandoned New York subway stat...
# 1  A peculiar mansion built by the troubled heir ...
# 2  The largest puppetry museum in the USA houses ...
# 3  The site of a tragic massacre that spawned a m...
# 4  Walk through the actual strap iron cells and s...
#
#                                          placeNearby  \
# 0  The Sugar House Prison Window,African Burial G...
# 1  Rosicrucian Park,Santana Row Chess Plaza,Rosic...
# 2  Breman Museum,The Consulate,Atlanta Monetary M...
# 3  The Long Island Puppet Theater,Fire Island Lig...
# 4  Old Plank Road,Felicity, California: Center of...
#
#                                          placeAdress  placeAlt  placeLong  \
# 0  31 Centre St New York, New York, 10007 United ...   40.7134   -74.0046
# 1  525 South Winchester Boulevard San Jose, Calif...   37.3189  -121.9506
# 2      1404 Spring St Atlanta, Georgia United States   33.7927   -84.3896
# 3  112 Ocean Avenue Amityville, New York, 11701 U...   40.6665   -73.4143
# 4  1 Prison Hill Rd Yuma, Arizona, 85364 United S...   32.7266  -114.6144
#
#                                         placeEditors         placePubDate  \
# 0  Rebekah OttoAnnetta BlackAllancharding407wythe...  2010-05-08 00:00:00
# 1  mbisonAvoiding RegretPrestonWCollinDestination...  2008-11-21 00:00:00
# 2  kendallmbaileyMartinandydoesitWe All Pod Down ...  2018-11-12 00:00:00
# 3  EricGrundhauserMandrewPatinkinlendog666MartinR...  2013-10-17 00:00:00
# 4  desertfairymbisonCorpseLady84Avoiding RegretEx...  2010-04-01 00:00:00
#
#                                     placeRelatedList  \
# 0  African Burial Ground National Monument,Tunnel...
# 1  Santana Row Chess Plaza,Rosicrucian Park,Rosic...
# 2  Breman Museum,Atlanta Monetary Museum,The Cons...
# 3  The Long Island Puppet Theater,Fire Island Lig...
# 4  Felicity, California: Center of the World,Vall...
#
#                                    placeRelatedPlace  \
# 0  Crystal Palace Subway,Moscow Metro Stations,Ro...
# 1  Casa de Piedra (Stone House),Portmeirion Villa...
# 2  Portland Puppet Museum,Museu da Marioneta (Mus...
# 3  Conanicut Island Lighthouse,Lovell Health Hous...
# 4  Buckley's Cave,Palazzo d'Avalos,Oxford Castle ...
#
#                                             placeURL
# 0  https://www.atlasobscura.com/places/city-hall-...
# 1  https://www.atlasobscura.com/places/winchester...
# 2  https://www.atlasobscura.com/places/center-for...
# 3  https://www.atlasobscura.com/places/amityville...
# 4  https://www.atlasobscura.com/places/yuma-terri...

# %%
print(len(data.columns))
# Out:
# 15

# %%
data.shape
# Out:
# (1199, 15)

# %%
data.info
# Out:
# <bound method DataFrame.info of                          placeName  \
# 0                City Hall Station
# 1     The Winchester Mystery House
# 2         Center for Puppetry Arts
# 3          Amityville Horror House
# 4          Yuma Territorial Prison
# ...                            ...
# 1194         Old Tunnel Bat Colony
# 1195               The Bunny Hutch
# 1196                 The Washhouse
# 1197      Takeshima Fantasy Museum
# 1198    Dead Children's Playground
#
#                                               placeTags  numPeopleVisited  \
# 0     subways,subterranean,infrastructure,subterrane...              1834
# 1     follies and grottoes,outsider architecture,ecc...              3723
# 2                         sesame street,puppets,museums               705
# 3     hoaxes and pseudoscience,haunted,film location...               367
# 4                          prisons,crime and punishment               422
# ...                                                 ...               ...
# 1194  bat caves,bats,tunnels,subterranean sites,cave...               226
# 1195  bunnies,giant animals,reptiles,snakes,zoos,ani...               119
# 1196                            speakeasies,bars,hidden               140
# 1197                                     shells,museums                27
# 1198          playgrounds,haunted,graveyards,cemeteries               289
#
#       numPeopleWant                                          placeDesc  \
# 0              8603  The first New York City subway was built and o...
# 1              5209  In 1886 an eccentric woman named Sarah Winches...
# 2              1027  If you know your Gonzo from your Gelflings, yo...
# 3               831  On a cold November night in 1974, Amityville, ...
# 4               833  On July 1, 1876, the first seven inmates enter...
# ...             ...                                                ...
# 1194            833  Just ten miles southeast of Fredericksburg is ...
# 1195            832  Not far from the coast of the Atlantic, Lord R...
# 1196            832  People passing by the Washhouse in Manchester,...
# 1197            831  The Takeshima Fantasy Museum in Gamagori, Japa...
# 1198            831  Cemeteries can be boring for kids. The weight ...
#
#                                          placeShortDesc  \
# 0     A beautiful and abandoned New York subway stat...
# 1     A peculiar mansion built by the troubled heir ...
# 2     The largest puppetry museum in the USA houses ...
# 3     The site of a tragic massacre that spawned a m...
# 4     Walk through the actual strap iron cells and s...
# ...                                                 ...
# 1194  Abandoned railroad tunnel is home to a colony ...
# 1195  The home of pigs, snakes, chameleons, and the ...
# 1196   This Manchester laundromat is hiding something.
# 1197  Shells collected from over a hundred different...
# 1198  What else would you call a playground hidden i...
#
#                                             placeNearby  \
# 0     The Sugar House Prison Window,African Burial G...
# 1     Rosicrucian Park,Santana Row Chess Plaza,Rosic...
# 2     Breman Museum,The Consulate,Atlanta Monetary M...
# 3     The Long Island Puppet Theater,Fire Island Lig...
# 4     Old Plank Road,Felicity, California: Center of...
# ...                                                 ...
# 1194  The Cartoon Saloon,Seashell Graves of Comfort ...
# 1195  The Witch of Pungo Statue,Edgar Cayce A.R.E. L...
# 1196  Jules Rimet Trophy Replica,Mr Smith's Dream,Th...
# 1197  Nana-chan Mannequin,Meoto Iwa ,Satsuki and Mei...
# 1198  The Grave of Miss Baker,MPTA-098,Lowe Mill ART...
#
#                                             placeAdress  placeAlt  placeLong  \
# 0     31 Centre St New York, New York, 10007 United ...   40.7134   -74.0046
# 1     525 South Winchester Boulevard San Jose, Calif...   37.3189  -121.9506
# 2         1404 Spring St Atlanta, Georgia United States   33.7927   -84.3896
# 3     112 Ocean Avenue Amityville, New York, 11701 U...   40.6665   -73.4143
# 4     1 Prison Hill Rd Yuma, Arizona, 85364 United S...   32.7266  -114.6144
# ...                                                 ...       ...        ...
# 1194  10619 Old San Antonio Rd. Fredericksburg, Texa...   30.1005   -98.8210
# 1195  1165 Jensen Dr Virginia Beach, Virginia United...   36.8349   -76.0026
# 1196   19 Shudehill  Manchester, England United Kingdom   53.4847    -2.2395
# 1197                  28-14 Takeshimacho Gamagori Japan   34.8150   137.2390
# 1198  Maple Hill Cemetery, 1351 McClung Ave SE 203 M...   34.7315   -86.5652
#
#                                            placeEditors         placePubDate  \
# 0     Rebekah OttoAnnetta BlackAllancharding407wythe...  2010-05-08 00:00:00
# 1     mbisonAvoiding RegretPrestonWCollinDestination...  2008-11-21 00:00:00
# 2     kendallmbaileyMartinandydoesitWe All Pod Down ...  2018-11-12 00:00:00
# 3     EricGrundhauserMandrewPatinkinlendog666MartinR...  2013-10-17 00:00:00
# 4     desertfairymbisonCorpseLady84Avoiding RegretEx...  2010-04-01 00:00:00
# ...                                                 ...                  ...
# 1194                         ClintonAnnetta Blackmbison  2010-02-02 00:00:00
# 1195                        allisonMorrganwendyandbelle  2017-12-11 00:00:00
# 1196                                        paulwhydall  2017-09-20 00:00:00
# 1197                                     Emerson Easley  2016-07-06 00:00:00
# 1198                    emilydmonsonrebecaschandellysha  2015-05-29 00:00:00
#
#                                        placeRelatedList  \
# 0     African Burial Ground National Monument,Tunnel...
# 1     Santana Row Chess Plaza,Rosicrucian Park,Rosic...
# 2     Breman Museum,Atlanta Monetary Museum,The Cons...
# 3     The Long Island Puppet Theater,Fire Island Lig...
# 4     Felicity, California: Center of the World,Vall...
# ...                                                 ...
# 1194  The Cartoon Saloon,Seashell Graves of Comfort ...
# 1195  Edgar Cayce A.R.E. Library,Mount Trashmore,The...
# 1196  Jules Rimet Trophy Replica,Mr Smith's Dream,Th...
# 1197  Satsuki and Mei's House,Nana-chan Mannequin,Me...
# 1198  Lowe Mill ARTS & Entertainment,The Grave of Mi...
#
#                                       placeRelatedPlace  \
# 0     Crystal Palace Subway,Moscow Metro Stations,Ro...
# 1     Casa de Piedra (Stone House),Portmeirion Villa...
# 2     Portland Puppet Museum,Museu da Marioneta (Mus...
# 3     Conanicut Island Lighthouse,Lovell Health Hous...
# 4     Buckley's Cave,Palazzo d'Avalos,Oxford Castle ...
# ...                                                 ...
# 1194  Stumphouse Tunnel,Ryūsendō Cave,Sudwala Caves,...
# 1195  Welt der Gifte,Reptile Zoo,Whipsnade White Lio...
# 1196   Fiume,Sunshine Laundromat,PS Air Bar,The Owl Bar
# 1197  Kenneth E. Stoddard Shell Museum,WIENXTRA-Spie...
# 1198  Frenier Cemetery,Howard Mausoleum Pyramid,Dean...
#
#                                                placeURL
# 0     https://www.atlasobscura.com/places/city-hall-...
# 1     https://www.atlasobscura.com/places/winchester...
# 2     https://www.atlasobscura.com/places/center-for...
# 3     https://www.atlasobscura.com/places/amityville...
# 4     https://www.atlasobscura.com/places/yuma-terri...
# ...                                                 ...
# 1194  https://www.atlasobscura.com/places/old-tunnel...
# 1195  https://www.atlasobscura.com/places/the-bunny-...
# 1196  https://www.atlasobscura.com/places/the-washho...
# 1197  https://www.atlasobscura.com/places/takeshimaf...
# 1198  https://www.atlasobscura.com/places/dead-child...
#
# [1199 rows x 15 columns]>

# %%
data.isna().sum()
# Out:
# placeName            0
# placeTags            2
# numPeopleVisited     0
# numPeopleWant        0
# placeDesc            0
# placeShortDesc       0
# placeNearby          0
# placeAdress          3
# placeAlt             0
# placeLong            0
# placeEditors         0
# placePubDate         0
# placeRelatedList     0
# placeRelatedPlace    2
# placeURL             0
# dtype: int64

# %%
data.describe().applymap('{:,.2f}'.format)
# Out:
#       numPeopleVisited numPeopleWant  placeAlt placeLong
# count         1,199.00      1,199.00  1,199.00  1,199.00
# mean            502.60      1,143.80     40.43    -62.87
# std             576.86        827.83     11.38     59.24
# min              13.00        801.00    -77.72   -156.96
# 25%             177.50        850.00     35.80   -105.20
# 50%             312.00        917.00     40.67    -80.12
# 75%             584.00        994.00     45.52     -7.21
# max           4,530.00      8,603.00     68.33    171.72

# %%
data.placePubDate
data.placePubDate2 = pd.to_datetime(data.placePubDate)
data.placePubDate2
data.placePubDate2['year'] = data.placePubDate2.dt.year
data.placePubDate2['year']
conteggio = data.placePubDate2['year'].value_counts(dropna=False)
print(conteggio)
# Out:
# 2016    161
# 2013    152
# 2017    148
# 2012    105
# 2010    104
# 2014    103
# 2018     96
# 2015     90
# 2009     83
# 2019     65
# 2011     60
# 2020     18
# 2008      9
# 2021      5
# Name: placePubDate, dtype: int64

# %%
import seaborn as sns

# %%
sns.set_theme()
grafico1 = sns.lineplot(data=conteggio)
grafico1.set(xlabel = "Year", ylabel = "Number of pubblications", title = "Number of pubblications per year")
# Out:
# [Text(0.5, 0, 'Year'),
#  Text(0, 0.5, 'Number of pubblications'),
#  Text(0.5, 1.0, 'Number of pubblications per year')]

# %%
print("L'anno con più pubblicazioni è stato l'anno:", data.placePubDate2['year'].value_counts().idxmax())
print("Il totale di pubblicazioni è stato di:", data.placePubDate2['year'].value_counts()[2016])
# Out:
# l'anno con più pubblicazioni è stato l'anno: 2016
# il totale di pubblicazioni è stato di: 161

# %%
top_meta = data.sort_values(["numPeopleVisited"], ascending = False).head(10)
top_meta[["placeName","numPeopleVisited"]]
# Out:
#                                        placeName  numPeopleVisited
# 773             Natural History Museum of London              4530
# 245                          Catacombes de Paris              4455
# 1008                                 Casa Batlló              3783
# 1                   The Winchester Mystery House              3723
# 639                       Paris Padlocks of Love              3668
# 27    Grand Central Terminal Whispering Gallery               3629
# 644                           The Last Bookstore              3614
# 332                   Saint Louis Cemetery No. 1              3590
# 16            La Brea Tar Pits Dragonfly Fossils              3551
# 313                                 Rocky Statue              3544

# %%
top_futur_meta = data.sort_values(["numPeopleWant"], ascending = False).head(10)
top_futur_meta[["placeName","numPeopleWant"]]
# Out:
#                               placeName  numPeopleWant
# 0                     City Hall Station           8603
# 112                   Highgate Cemetery           8206
# 223                   Leadenhall Market           7593
# 234                      The Wave Organ           7422
# 245                 Catacombes de Paris           7057
# 256                 The Evolution Store           6948
# 267      Magowan's Infinite Mirror Maze           6506
# 278  Underground Tunnels of Los Angeles           6439
# 289              Secret Tiled Staircase           6310
# 311                         Dream House           6007

# %%
var1 = data.numPeopleVisited
var2 = data.numPeopleWant
print(var1.corr(var2, method = "pearson"))
grafico2 = sns.scatterplot(x="numPeopleVisited", y="numPeopleWant", data=data);
grafico2
# Out:
# 0.4427840231389944
# <AxesSubplot:xlabel='numPeopleVisited', ylabel='numPeopleWant'>

# %%
data.head()
# Out:
#                       placeName  \
# 0             City Hall Station
# 1  The Winchester Mystery House
# 2      Center for Puppetry Arts
# 3       Amityville Horror House
# 4       Yuma Territorial Prison
#
#                                            placeTags  numPeopleVisited  \
# 0  subways,subterranean,infrastructure,subterrane...              1834
# 1  follies and grottoes,outsider architecture,ecc...              3723
# 2                      sesame street,puppets,museums               705
# 3  hoaxes and pseudoscience,haunted,film location...               367
# 4                       prisons,crime and punishment               422
#
#    numPeopleWant                                          placeDesc  \
# 0           8603  The first New York City subway was built and o...
# 1           5209  In 1886 an eccentric woman named Sarah Winches...
# 2           1027  If you know your Gonzo from your Gelflings, yo...
# 3            831  On a cold November night in 1974, Amityville, ...
# 4            833  On July 1, 1876, the first seven inmates enter...
#
#                                       placeShortDesc  \
# 0  A beautiful and abandoned New York subway stat...
# 1  A peculiar mansion built by the troubled heir ...
# 2  The largest puppetry museum in the USA houses ...
# 3  The site of a tragic massacre that spawned a m...
# 4  Walk through the actual strap iron cells and s...
#
#                                          placeNearby  \
# 0  The Sugar House Prison Window,African Burial G...
# 1  Rosicrucian Park,Santana Row Chess Plaza,Rosic...
# 2  Breman Museum,The Consulate,Atlanta Monetary M...
# 3  The Long Island Puppet Theater,Fire Island Lig...
# 4  Old Plank Road,Felicity, California: Center of...
#
#                                          placeAdress  placeAlt  placeLong  \
# 0  31 Centre St New York, New York, 10007 United ...   40.7134   -74.0046
# 1  525 South Winchester Boulevard San Jose, Calif...   37.3189  -121.9506
# 2      1404 Spring St Atlanta, Georgia United States   33.7927   -84.3896
# 3  112 Ocean Avenue Amityville, New York, 11701 U...   40.6665   -73.4143
# 4  1 Prison Hill Rd Yuma, Arizona, 85364 United S...   32.7266  -114.6144
#
#                                         placeEditors         placePubDate  \
# 0  Rebekah OttoAnnetta BlackAllancharding407wythe...  2010-05-08 00:00:00
# 1  mbisonAvoiding RegretPrestonWCollinDestination...  2008-11-21 00:00:00
# 2  kendallmbaileyMartinandydoesitWe All Pod Down ...  2018-11-12 00:00:00
# 3  EricGrundhauserMandrewPatinkinlendog666MartinR...  2013-10-17 00:00:00
# 4  desertfairymbisonCorpseLady84Avoiding RegretEx...  2010-04-01 00:00:00
#
#                                     placeRelatedList  \
# 0  African Burial Ground National Monument,Tunnel...
# 1  Santana Row Chess Plaza,Rosicrucian Park,Rosic...
# 2  Breman Museum,Atlanta Monetary Museum,The Cons...
# 3  The Long Island Puppet Theater,Fire Island Lig...
# 4  Felicity, California: Center of the World,Vall...
#
#                                    placeRelatedPlace  \
# 0  Crystal Palace Subway,Moscow Metro Stations,Ro...
# 1  Casa de Piedra (Stone House),Portmeirion Villa...
# 2  Portland Puppet Museum,Museu da Marioneta (Mus...
# 3  Conanicut Island Lighthouse,Lovell Health Hous...
# 4  Buckley's Cave,Palazzo d'Avalos,Oxford Castle ...
#
#                                             placeURL
# 0  https://www.atlasobscura.com/places/city-hall-...
# 1  https://www.atlasobscura.com/places/winchester...
# 2  https://www.atlasobscura.com/places/center-for...
# 3  https://www.atlasobscura.com/places/amityville...
# 4  https://www.atlasobscura.com/places/yuma-terri...

# %%
d = {}
n = len(data)

for i in range(n):
    l = []
    l = data.iloc[i]["placeEditors"]
    l = l.split(' ')
    if not l in d:
# Out:
# ['Rebekah', 'OttoAnnetta', 'BlackAllancharding407wythembisonccharding407ffosterc827MMike', 'HerjefferyAAllanHabicuriousjjrc2692oofftrackplanetmmbisonSeth', 'TeicherwytheAnnetta', 'Blacklittlebrumble']
